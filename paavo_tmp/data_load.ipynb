# %%
## Data loading

# %%
import pandas as pd
import numpy as np
import psycopg2

# %%
pg_config = {
    'host': 'localhost',
    'port': 5432,
    'database': 'project_db',
    'user': 'postgres',
    'password': 'postgres'
}
conn = psycopg2.connect(**pg_config)
