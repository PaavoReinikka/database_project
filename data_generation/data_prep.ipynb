# %% [markdown]
# ## How to generate the data for DB
#
#
# * **Suppliers** and **Customers** can be generated independently.
# * For *any*/*every* Supplier, some **Products** can be generated (dependence).
# * For *any*/*every* Customer, some **Orders** can be generated (dep.).
# * For *any*/*every* Order, some **Order_items** and a **Shipment** can be generated (2 deps.).
#     * for every **Order_item**, one existing product have to selected.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# %%
random_countries = [
    "Finland", "Sweden", "Norway", "Denmark", "Iceland",
    "Germany", "France", "Italy", "Spain", "Portugal",
    "Netherlands", "Belgium", "Switzerland", "Austria", "Poland",
    "Czech Republic", "Slovakia", "Hungary", "Greece", "Turkey",
    "United Kingdom", "Ireland", "Russia", "Ukraine", "Romania",
    "Bulgaria", "Croatia", "Serbia", "Slovenia", "Lithuania",
    "Latvia", "Estonia", "Belarus", "Moldova", "Albania",
    "North Macedonia", "Bosnia and Herzegovina", "Montenegro", "Kosovo",
    "Cyprus", "Malta", "Luxembourg", "Liechtenstein", "Monaco",
]

get_random_country = lambda: np.random.choice(random_countries)

# %%
path = "../data/"
#fname = "products.csv" 
fname = "companies.csv"
#fname = "common-surnames-by-country.csv"
#fname = "common-forenames-by-country.csv"
#fname = "male.txt"
#fname = "female.txt"

# %%
data = pd.read_csv(path + fname)
data.head()
# Out:
#   Company Name  Rating   Review Count Company Type       Headquarters  \
# 0          TCS     3.9  16.1k Reviews       Public  Mumbai + 156 more
# 1    Accenture     4.0  13.9k Reviews      Private   Dublin + 40 more
# 2   ICICI Bank     4.1  12.6k Reviews       Public   Mumbai + 42 more
# 3    Cognizant     3.9    12k Reviews      Private  Teaneck + 39 more
# 4    HDFC Bank     4.0  10.8k Reviews       Public   Mumbai + 46 more
#
#     Company Age Number of Employees
# 0  52 years old    10000+ employees
# 1  31 years old    10000+ employees
# 2  26 years old    10000+ employees
# 3  26 years old    10000+ employees
# 4  26 years old    10000+ employees

# %%
as_product = lambda x: (x["Product Name"], x["Category"], round(x["SellPrice"]*0.0109,2))
as_product(data.iloc[0])
# Out:
# ('Cologne Fragrance', 'Fragrance-Women', np.float64(34.01))

# %%
locations = [item.split()[0] for item in data.Headquarters.unique()]
locations
# Out:
# ['Mumbai',
#  'Dublin',
#  'Mumbai',
#  'Teaneck',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Paris',
#  'Pune',
#  'Noida',
#  'New',
#  'Navi',
#  'New',
#  'Bangalore',
#  'New',
#  'Berkshire',
#  'Ahmedabad',
#  'New',
#  'Mumbai',
#  'Washington',
#  'Bangalore',
#  'Mumbai',
#  'Seoul',
#  'New',
#  'Stockholm',
#  'New',
#  'Mumbai',
#  'Mumbai',
#  'Paris',
#  'Mumbai',
#  'Mumbai',
#  'London',
#  'Navi',
#  'Hyderabad',
#  'Pittsford',
#  'Tysons',
#  'California',
#  'Mumbai',
#  'Gurugram',
#  'Bangalore',
#  'Pune',
#  'Bangalore',
#  'Mumbai',
#  'Bengaluru',
#  'Shenzhen',
#  'London',
#  'Noida',
#  'London',
#  'Espoo',
#  'New',
#  'Bengaluru',
#  'Chennai',
#  'Seoul',
#  'Dongguan',
#  'Ahmedabad,',
#  'Kolkata',
#  'Chennai',
#  'Kochi',
#  'Tokyo,',
#  'Ann',
#  'Mumbai',
#  'Sttugart',
#  'Hosur',
#  'Bengaluru',
#  'Minnesota',
#  'New',
#  'Bangalore',
#  'Gurugram',
#  'Mumbai',
#  'Hyderabad',
#  'New',
#  'Kolkata',
#  'Hyderabad',
#  'California',
#  'Canonsburg,Pennsylvania',
#  'Troy',
#  'Gurugram',
#  'Florida',
#  'New',
#  'Noida',
#  'New',
#  'Mumbai',
#  'Ahmedabad',
#  'Texas',
#  'Thrissur',
#  'Gurgaon',
#  'Illinois',
#  'Chicago',
#  'Greater',
#  'Hyderabad',
#  'Amsterdam',
#  'Michigan',
#  'Edinburgh',
#  'Paris',
#  'Bangalore',
#  'Chennai',
#  'Florida',
#  'Bezons',
#  'Pune',
#  'New',
#  'Jaipur',
#  'Hyderabad',
#  'Hyderabad',
#  'Tokyo',
#  'Noida',
#  'Illinois',
#  'Pune',
#  'Amstelveen',
#  'Chennai',
#  'Montreal',
#  'New',
#  'Rueil-Malmaison',
#  'Noida',
#  'Mumbai',
#  'Moline',
#  'Bengaluru',
#  'Zurich',
#  'Los',
#  'Mumbai',
#  'New',
#  'Gurugram',
#  'London',
#  'Bangalore',
#  'Dubai',
#  'New',
#  'New',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Gurgaon',
#  'Pune',
#  'Columbus',
#  'Frankfurt',
#  'New',
#  'New',
#  'Aliso',
#  'Durham',
#  'Gurgaon',
#  'London',
#  'San',
#  'New',
#  'Brussels',
#  'New',
#  'New',
#  'Gurgaon',
#  'Vadodara',
#  'Kanpur',
#  'Delhi',
#  'London,England',
#  'Kolkata',
#  'Copenhagen',
#  'San',
#  'Toronto',
#  'Chesterfield',
#  'Chennai',
#  'New',
#  'Chennai',
#  'Vevey',
#  'Ahmedabad',
#  'San',
#  'Bhopal',
#  'Banglore',
#  'Iwata',
#  'Bengaluru',
#  'Kolkata',
#  'Gurgaon',
#  'Thane',
#  'Charlotte',
#  'Bangalore',
#  'Bangalore',
#  'Mumbai',
#  'Diemen',
#  'Faridabad',
#  'Bangalore',
#  'Bangalore',
#  'Tirupati',
#  'Virginia',
#  'Gothenberg',
#  'Panchkula',
#  'Florham',
#  'San',
#  'Chennai',
#  'London',
#  'Mumbai',
#  'Southborough',
#  'Pune',
#  'West',
#  'Pune',
#  'Bhopal',
#  'Gurgaon',
#  'Bangalore',
#  'Delhi',
#  'Chennai',
#  'Tamil',
#  'New',
#  'California',
#  'Sigma',
#  'Bangalore',
#  'Noida',
#  'Plano',
#  'Hyderabad',
#  'Osaka',
#  'Benton',
#  'London',
#  'Kolkata',
#  'Gurugram',
#  'Tokyo',
#  'Aurangabad',
#  'Bengaluru',
#  'Noida',
#  'Secunderabad',
#  'Bangalore',
#  'Noida',
#  'Chennai',
#  'California',
#  'Brookfield',
#  'Zurich',
#  'Tokyo',
#  'Berne',
#  'Marousi',
#  'Bangalore',
#  'Noida',
#  'Bangalore',
#  'Berlin',
#  'Hoshiarpur',
#  'Suwon-si',
#  'Noida',
#  'Chennai',
#  'Cork',
#  'Slough',
#  'Saint',
#  'Florida',
#  'Paris',
#  'Mumbai',
#  'New',
#  'Fornebu',
#  'Gurgaon',
#  'Rocester',
#  'Hyderabad',
#  'Pune',
#  'Ludhiana',
#  'Gurugram',
#  'Paris',
#  'Pune',
#  'Singapore',
#  'Geneva',
#  'Varanasi',
#  'Noida',
#  'Mumbai',
#  'Mumbai',
#  'New',
#  'New',
#  'Bengaluru',
#  'Bangalore',
#  'New',
#  'Bonn',
#  'Cincinnati',
#  'Pune',
#  'Ahmedabad',
#  'Bentonville',
#  'Hyderabad',
#  'Boston',
#  'Abu',
#  'Bethesda',
#  'New',
#  'Basel',
#  'Noida',
#  'Toronto',
#  'Boston',
#  'Los',
#  'Mumbai',
#  'London',
#  'Washington,D.C.',
#  'Gurgaon',
#  'Leverkusen',
#  'Noida',
#  'Tokyo',
#  'Pune',
#  'Copenhagen,Denmark',
#  'Chandigarh',
#  'Selangor',
#  'Bangalore',
#  'Mumbai',
#  'Pune',
#  'Hyderabad',
#  'London',
#  'California',
#  'Chennai',
#  'Gurgaon',
#  'Blue',
#  'New',
#  'Mumbai',
#  'Bengaluru',
#  'Gurugram',
#  'Gurgaon',
#  'New',
#  'Miami',
#  'Ludhiana',
#  'Falls',
#  'Minnesota',
#  'Norwalk,Connecticut',
#  'Noida',
#  'North',
#  'Memphis',
#  'Hertfordshire',
#  'Gurgaon',
#  'New',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'New',
#  'Ahmedabad',
#  'Gurgaon',
#  'Morelia',
#  'Mumbai',
#  'Espoo',
#  'Taipei',
#  'Los',
#  'Hyderabad',
#  'Faridabad',
#  'The',
#  'Chicago',
#  'Atlanta',
#  'Santa',
#  'Kariya',
#  'San',
#  'Chicago',
#  'New',
#  'Hyderabad',
#  'California',
#  'Noida',
#  'Vadodara',
#  'Udaipur',
#  'New',
#  'Pune',
#  'East',
#  'Noida,UP',
#  'Chicago,IL',
#  'Amsterdam',
#  'Ahmedabad',
#  'Kolkata',
#  'New',
#  'Chennai',
#  'Gurgaon,Haryana',
#  'Manesar',
#  'Indore',
#  'Mumbai,India',
#  'Milpitas,CA',
#  'Marseille',
#  'Gothenburg',
#  'New',
#  'Pune',
#  'New',
#  'Reston',
#  'Bangalore',
#  'Mumbai',
#  'Mumbai,Maharashtra',
#  'Lausanne',
#  'New',
#  'Pontedera',
#  'Bengaluru',
#  'Stuttgart',
#  'Nagpur',
#  'Chennai',
#  'Brentford',
#  'Chennai',
#  'New',
#  'Lucknow',
#  'Gerlingen',
#  'Paris',
#  'Osaka',
#  'Hyderabad',
#  'Minnesota',
#  'Banglore',
#  'Stockholm',
#  'Mumbai',
#  'Johannesburg',
#  'Muscat',
#  'Chicago',
#  'Columbia',
#  'Plano,Texas',
#  'Paris',
#  'Mumbai',
#  'Walldorf',
#  'Coimbatore',
#  'Essen',
#  'Mumbai',
#  'Paris',
#  'San',
#  'Secunderabad',
#  'New',
#  'Toyota',
#  'Gujarat',
#  'Gurgaon',
#  'Dallas',
#  'Hook,Hampshire',
#  'Dubai',
#  'Coimbatore',
#  'Chennai',
#  'Mumbai',
#  'Banglore',
#  'New',
#  'Coimbatore,Tamilnadu',
#  'Navi',
#  'Hyderabad',
#  'Chicago',
#  'Atlanta',
#  'La',
#  'Al',
#  'Indore',
#  'Melbourne',
#  'Hyderabad',
#  'Pune',
#  'London',
#  'Faridabad',
#  'New',
#  'Massachusetts',
#  'New',
#  'Atlanta',
#  'Jalgaon',
#  'Munich',
#  'Gujarat',
#  'Saint-Ouen',
#  'New',
#  'London',
#  'Nashik',
#  'Wilmington,DE,United',
#  'Hyderabad',
#  'Shenzhen',
#  'Hyderabad,Telangana',
#  'Redmond',
#  'Nanterre',
#  'Montreal',
#  'New',
#  'Vizcaya',
#  'Hyderabad',
#  'Kolkata',
#  'Gurgaon',
#  'Greater',
#  'London',
#  'California',
#  'Chennai',
#  'Hyderabad',
#  'Hyderabad',
#  'Chicago',
#  'Mannheim',
#  'Mumbai,India',
#  'New',
#  'Udaipur',
#  'Gujarat',
#  'Gurugram',
#  'Henderson',
#  'Chennai',
#  'Shenzhen',
#  'Gurgaon,Haryana',
#  'Michigan',
#  'Jharkhand',
#  'Sarasota',
#  'Coimbatore',
#  'Chennai',
#  'Stuttgart,Germany',
#  'Lake',
#  'Mumbai',
#  'Chicago',
#  'Lagos',
#  'Cambridge,Cambridgeshire',
#  'Chertsey',
#  'Gurgaon',
#  'London',
#  'Stockholm',
#  'Faridabad',
#  'Bangalore',
#  'New',
#  'Jeddah',
#  'Faridabad',
#  'Munich',
#  'Hyderabad',
#  'Ann',
#  'Hopkinton,MA',
#  'GURUGRAM',
#  'Mumbai',
#  'Noida',
#  'Banglore',
#  'Hyderabad',
#  'Kerala',
#  'Jaipur',
#  'Chennai',
#  'Dublin',
#  'Mumbai',
#  'Bangalore',
#  'London',
#  'Hong',
#  'Norwalk',
#  'Chennai',
#  'Mumbai',
#  'Bangalore',
#  'Billerica',
#  'Lainate',
#  'Irvine',
#  'Kalol',
#  'Bhubaneswar',
#  'New',
#  'Delhi',
#  'New',
#  'Miami',
#  'West',
#  'New',
#  'Bangalore',
#  'Detroit',
#  'Copenhagen',
#  'Kolkata',
#  'New',
#  'Maharashtra',
#  'Espoo',
#  'Aurangabad',
#  'Basel',
#  'Hyderabad',
#  'Pune',
#  'Redditch',
#  'Hopkinton',
#  'Jacksonville',
#  'Paris',
#  'Essen',
#  'Thane',
#  'Agra',
#  'Hyderabad',
#  'New',
#  'Gurugram',
#  'Schaffhausen',
#  'Farmington',
#  'Des',
#  'Noida',
#  'Kolkata',
#  'Stamford',
#  'Clichy',
#  'Bangalore',
#  'Gurgaon',
#  'Navi',
#  'Hanover',
#  'Hamamatsu',
#  'Eastleigh',
#  'Schaffhausen',
#  'Pune',
#  'New',
#  'Karur',
#  'Paranaque',
#  'Chennai',
#  'Lake',
#  'Hyderabad',
#  'Chennai',
#  'Bangalore,',
#  'Kolkata',
#  'Banglore',
#  'Southfield',
#  'Pune',
#  'Dallas',
#  'Bengaluru',
#  'Surat',
#  'Bengaluru',
#  'Denmark',
#  'Noida',
#  'Howrah',
#  'Aarhus',
#  'Chennai',
#  'San',
#  'Navi',
#  'Mumbai',
#  'Noida',
#  'Jamshedpur',
#  'Ludwigshafen',
#  'Noida',
#  'Hyderabad',
#  'Worli',
#  'Westborough',
#  'Madrid',
#  'Los',
#  'New',
#  'Punjab',
#  'Muscat',
#  'Irving',
#  'Lille',
#  'Lucknow',
#  'Cochin',
#  'Maryland',
#  'Bad',
#  'Chennai',
#  'Mumbai',
#  'Boulogne-Billancourt',
#  'Pune',
#  'Jaipur',
#  'Riyadh',
#  'Shizuoka',
#  'Monroe',
#  'Greater',
#  'Panchkula',
#  'New',
#  'Pune',
#  'Gurgaon',
#  'Paris',
#  'Mumbai',
#  'Hyderabad',
#  'Hyderabad',
#  'Chennai',
#  'Madurai',
#  'Englewood,Colorado',
#  'Pune',
#  'Rewari',
#  'Secunderabad',
#  'Ponzano',
#  'Gurgaon',
#  'Montreal',
#  'Seattle',
#  'Delhi',
#  'Dhahran',
#  'Hyderabad',
#  'Kolkata',
#  'Rajkot',
#  'Ahmedabad',
#  'Navi',
#  'Houston',
#  'Mumbai',
#  'Ruwi',
#  'New',
#  'Jaipur,India',
#  'Mumbai',
#  'Gurgaon',
#  'New',
#  'Pune',
#  'Muscat',
#  'Indore',
#  'Windsor',
#  'Plantation,FL',
#  'Newbury',
#  'Cairo',
#  'Seoul',
#  'Calcutta',
#  'GURGAON',
#  'Vapi,Maharashtra',
#  'Ahmadi',
#  'Gurgaon',
#  'Munich',
#  'Gurugram',
#  'North',
#  'Siruseri',
#  'Staffordshire',
#  'Chennai',
#  'Noida',
#  'DELHI',
#  'New',
#  'New',
#  'Chennai',
#  'Bengaluru',
#  'Navi',
#  'Bellandur',
#  'Pune',
#  'Milwaukee',
#  'New',
#  'Gurgaon',
#  'Ontario',
#  'Schenectady,NY,United',
#  'New',
#  'Memphis',
#  'Chennai',
#  'Sacramento',
#  'Gothenburg',
#  'Evanston',
#  'Lincolnshire',
#  'North',
#  'Dubai,United',
#  'Gurgaon',
#  'Haryana',
#  'Santa',
#  'Paris,France',
#  'Mc',
#  'Lahore',
#  'Reston',
#  'Chennai',
#  'Stuttgart',
#  'Kansas',
#  'Johannesburg',
#  'Tysons',
#  'Chennai',
#  'Centurion',
#  'John',
#  'Noida',
#  'San',
#  'Chennai',
#  'Ahmedabad',
#  'Faridabad',
#  'Gurugram',
#  'Navi',
#  'Hyderabad',
#  'Osaka',
#  'New',
#  'Vadodara',
#  'Chennai',
#  'Meghalaya',
#  'Gurgaon',
#  'Phagwara',
#  'Florida',
#  'Visakhapatnam',
#  'Miami',
#  'Gurugram',
#  'Chennai',
#  'Stamford',
#  'Hyderabad',
#  'Kolkata,India',
#  'Ahmedabad',
#  'Toronto',
#  'Kerala',
#  'Singapore',
#  'Gurgaon',
#  'New',
#  'Pune',
#  'Hyderabad',
#  'Helsinki',
#  'Chicago,IL,United',
#  'Chandigarh',
#  'Tokyo',
#  'Gurgaon',
#  'Tokyo',
#  'Saint',
#  'Santa',
#  'Bangalore',
#  'Bangalore',
#  'San',
#  'Pune',
#  'New',
#  'Chennai',
#  'San',
#  'Gurgaon',
#  'Mumbai',
#  'Mumbai',
#  'New',
#  'Ingolstadt',
#  'Denham',
#  'Jaipur',
#  'Gardena,CA,United',
#  'Jaipur',
#  'Sulaibiya',
#  'Pune',
#  'Mumbai',
#  'New',
#  'Elgin,IL',
#  'Delhi',
#  'Gurgaon',
#  'Mumbai',
#  'Lucknow',
#  'Lucknow',
#  'New',
#  'Bengaluru',
#  'Coimbatore',
#  'Paris',
#  'Kolkata',
#  'Columbus',
#  'Coimbatore',
#  'Chennai',
#  'Kochi',
#  'Eindhoven',
#  'Gurugram',
#  'Bangalore,India',
#  'Pune',
#  'Neuilly-sur-Seine',
#  'Chennai',
#  'Chandigarh',
#  'Saint-Ouen',
#  'New',
#  'Bengaluru',
#  'Navi',
#  'Thiruvananthapuram',
#  'Mumbai,India',
#  'Gurgaon',
#  'Bangalore',
#  'Minneapolis',
#  'Minneapolis',
#  'Kochi',
#  'Navi',
#  'Noida',
#  'Sharjah',
#  'St',
#  'Hyderabad',
#  'Dubai',
#  'Stockholm,Sweden',
#  'Waltham',
#  'Santa',
#  'Atlanta',
#  'Chennai',
#  'Clermont-Ferrand',
#  'Bayern',
#  'Shenzhen',
#  'Plainsboro',
#  'Mumbai',
#  'Mumbai,India',
#  'Lucknow',
#  'Westborough,MA,United',
#  'Gutersloh',
#  'New',
#  'Gurugram',
#  'Zürich,Switzerland',
#  'Navi',
#  'Mountain',
#  'Mumbai',
#  'Mumbai',
#  'Herzogenaurach',
#  'Bhubaneshwar',
#  'Hyderabad',
#  'Hyderabad',
#  'London,England,United',
#  'Deerfield',
#  'Paris',
#  'Kozhikode',
#  'Mumbai',
#  'Udaipur',
#  'Burbank',
#  'Kolkata',
#  'Bangalore',
#  'Rewari',
#  'Bengaluru',
#  'Gandhinagar',
#  'Epsom',
#  'Franklin,TN',
#  'Singapore',
#  'Chennai',
#  'London',
#  'Kolkata',
#  'Gurugram',
#  'Kolkata',
#  'Nagano',
#  'Ohta-ku',
#  'Bangalore',
#  'Ahmedabad',
#  'Bavaria',
#  'London',
#  'Nagpur,Maharashtra',
#  'Bangalore',
#  'Bangalore',
#  'Atlanta',
#  'Chennai,Tamil',
#  'Gurgaon',
#  'New',
#  'New',
#  'Manipal',
#  'Noida',
#  'Palo',
#  'Gurgaon',
#  'New',
#  'Navi',
#  'Secunderabad',
#  'Missouri',
#  'Thane',
#  'Ras',
#  'Wisconsin',
#  'Faridabad',
#  'Essen',
#  'Pune',
#  'Northbrook',
#  'Chennai',
#  'Thiruvananthapuram',
#  'New',
#  'Vadodara',
#  'Ahmadi',
#  'Punjab',
#  'Battle',
#  'Pune',
#  'Bhiwadi',
#  'Hamburg',
#  'Kolkata',
#  'Vadodara',
#  'Noida',
#  'Rajkot',
#  'Tokyo',
#  'Riyadh',
#  'Vellore',
#  'Jaipur',
#  'Santa',
#  'Faridabad',
#  'Tokyo',
#  'Bangalore',
#  'New',
#  'New',
#  'Gurgaon',
#  'Gujrat',
#  'Ahmedabad',
#  'Kolkata',
#  'Abu',
#  'Gurugram',
#  'Surat',
#  'Male',
#  'Birmingham',
#  'Southfield',
#  'Madurai',
#  'North',
#  'Mumbai',
#  'Nagoya',
#  'Safat',
#  'Bengaluru',
#  'Singapore',
#  'London',
#  'London',
#  'El',
#  'Lucknow',
#  'Teaneck',
#  'San',
#  'Southfield,MI',
#  'Noida',
#  'Pune',
#  'Ahmedabad',
#  'Salem',
#  'Chicago',
#  'Minneapolis',
#  'Middlesex',
#  'Noida',
#  'Maryland',
#  'New',
#  'Mohali',
#  'Thiruvananthapuram',
#  'Quarry',
#  'Helsinki',
#  'Kolkata',
#  'Maharashtra',
#  'Mountain',
#  'Al-Khobar',
#  'Kolkata',
#  'Zurich',
#  'Herzogenaurach',
#  'London',
#  'Melsungen',
#  'Gurugram',
#  'Sunnyvale',
#  'Simi',
#  'Coimbatore',
#  'Burnsville',
#  'Coimbatore',
#  'Chicago',
#  'Bangalore',
#  'Yamuna',
#  'London',
#  'Waltham,MA',
#  'Noida',
#  'Rajkot',
#  'Illinois',
#  'Bengaluru',
#  'Yokohama-shi,Kanagawa',
#  'Pittsford',
#  'Dong-Gu',
#  'Bengaluru',
#  'Jaipur',
#  'Hampshire',
#  'Kolkata',
#  'New',
#  'Bengaluru',
#  'Ahmedabad',
#  'Tokyo',
#  'Dublin',
#  'Dallas',
#  'Pune',
#  'Kanpur',
#  'Gurugram',
#  'Tokyo',
#  'Madurai',
#  'Nagpur',
#  'Bangalore',
#  'New',
#  'Chennai',
#  'Corbetta',
#  'Beijing',
#  'Bengaluru',
#  'Coimbatore',
#  'Hoffman',
#  'Bina',
#  'Bangalore',
#  'Graz',
#  'Bangalore',
#  'New',
#  'Bengaluru',
#  'Bengaluru',
#  'Lisle,IL',
#  'Thane',
#  'Thane',
#  'Greater',
#  'Doha',
#  'Pune',
#  'Thiruvananthapuram',
#  'Aurangabad',
#  'Mc',
#  'Mumbai,India',
#  'Aichi',
#  'Oak',
#  'Raichur',
#  'Dubai',
#  'Rawang',
#  'Howrah',
#  'Boston,Massachusetts',
#  'Hanover',
#  'Munich',
#  'Daman',
#  'New',
#  'Kolkata',
#  'Gurgaon',
#  'Pullach',
#  'Bangalore',
#  ...]

# %%
def generate_dates(start, delta, freq='D', n=3):
    """
    Generate a list of n random dates within a specified range.
    
    Parameters:
    - start (datetime): The starting date.
    - delta (timedelta): The time delta to define the end date.
    - freq (str): Frequency string for date range generation (default is 'D' for
        daily).
    - n (int): Number of random dates to generate (default is 3).
    
    Returns:
    - tuple: A tuple containing two lists:
        - List of datetime objects.
        - List of date strings in 'YYYY-MM-DD' format.
    
    """
    end = pd.to_datetime(start+delta).date()
    seed = pd.date_range(start=start, end=end, freq=freq)
    dates = np.random.choice(seed, size=n, replace=False)
    dates = sorted(dates)
    py_dates = [pd.Timestamp(date).to_pydatetime() for date in dates]
    return py_dates, [str(date).split("T")[0] for date in dates]

def sample_quantity(p: float = 0.7, max_qty: int | None = None) -> int:
    """
    Return a discrete quantity with mode at 1 using a geometric distribution.
    - p: success probability (higher p => more 1s, lower mean)
    - max_qty: optional upper cap for quantities (e.g., stock or policy)
    """
    q = int(np.random.geometric(p))  # support: 1, 2, ...; P(1)=p; E[q]=1/p
    if max_qty is not None:
        q = min(q, int(max_qty))
    return q

# %%
generate_dates(datetime(2020, 1, 1), delta=timedelta(weeks=1))
# Out:
# ([datetime.datetime(2020, 1, 2, 0, 0),
#   datetime.datetime(2020, 1, 5, 0, 0),
#   datetime.datetime(2020, 1, 8, 0, 0)],
#  ['2020-01-02', '2020-01-05', '2020-01-08'])

# %%
datetime(2020, 1, 1) + timedelta(days=7)
# Out:
# datetime.datetime(2020, 1, 8, 0, 0)

# %% [markdown]
# ### Suppliers:
# ```
# CREATE TABLE Suppliers (
#     supplier_id SERIAL PRIMARY KEY,
#     name VARCHAR(255) NOT NULL,
#     contact_info VARCHAR(255),
#     country VARCHAR(100)
# );
# ```
#
# **id**: 1-100
# **name**: Combining from **forenames/surnames**
# **contact_info**: Leave to null
# **country**: From random_countries

# %% [markdown]
# ### Customers
#
# ```
# CREATE TABLE Customers (
#     customer_id SERIAL PRIMARY KEY,
#     name VARCHAR(255) NOT NULL,
#     location VARCHAR(255),
#     email VARCHAR(255) UNIQUE NOT NULL
# );
# ```
# **customer_id**: 1-100
# **name**: Combining from **forenames/surnames**
# **localtion**: From locations
# **email**: first.lastname@randomprovider.random_domain

# %% [markdown]
# ### Products
#
# ```
# CREATE TABLE Products (
#     product_id SERIAL PRIMARY KEY,
#     name VARCHAR(255) NOT NULL,
#     category VARCHAR(100),
#     price DECIMAL(10, 2) NOT NULL,
#     supplier_id INT REFERENCES Suppliers(supplier_id),
#     stock_quantity INT NOT NULL
# );
# ```
#
# * for each **supplier_id** in [1,100]:
#     * **name**: Products.name
#     * **category**: Products.category
#     * **price**: factor*Product.SellPrice
#     * **supplier_id**: ...
#     * **stock_quamtity**: random.randomint(0,1e4) # note special case if 0

# %%
path = "../data/"
fname = "product_data.csv" 
data = pd.read_csv(path + fname)
data.tail()
# Out:
#       S.No       BrandName        Product ID  \
# 4561  4562  crimsoune club   CRIMSOUNE CLUB6
# 4562  4563  crimsoune club   CRIMSOUNE CLUB7
# 4563  4564  crimsoune club   CRIMSOUNE CLUB8
# 4564  4565  crimsoune club   CRIMSOUNE CLUB9
# 4565  4566  crimsoune club  CRIMSOUNE CLUB10
#
#                               Product Name  \
# 4561   CRIMSOUNE CLUB6 - Westernwear-Women
# 4562   CRIMSOUNE CLUB7 - Westernwear-Women
# 4563   CRIMSOUNE CLUB8 - Westernwear-Women
# 4564   CRIMSOUNE CLUB9 - Westernwear-Women
# 4565  CRIMSOUNE CLUB10 - Westernwear-Women
#
#                                              Brand Desc  \
# 4561  solid hood poly cotton womens sweatshirt - yellow
# 4562  striped v-neck cotton womens casual shirt - white
# 4563                  womens slim fit solid shirt - red
# 4564      printed lyocell round neck womens top - green
# 4565                 womens grey solid jumpsuit - denim
#
#                                            Product Size Currancy   MRP  \
# 4561                    Size:Large,Medium,Small,X-Large      Rs.  1699
# 4562       Size:Large,Medium,X-Large,XX-Large,XXX-Large      Rs.  1299
# 4563                          Size:Large,Medium,X-Large      Rs.  1299
# 4564  Size:Large,Medium,Small,X-Large,XX-Large,XXX-L...      Rs.  1399
# 4565                 Size:Large,Medium,X-Large,XX-Large      Rs.  2499
#
#       SellPrice Discount           Category
# 4561        849  50% off  Westernwear-Women
# 4562       1039  20% off  Westernwear-Women
# 4563        649  50% off  Westernwear-Women
# 4564        979  30% off  Westernwear-Women
# 4565       1249  50% off  Westernwear-Women

# %%
# lambda to extract product info with price adjusted from Rs to Euros
as_product = lambda x: (x["Product Name"], x["Category"], round(x["SellPrice"]*0.0109,2), np.random.randint(1,101), 1000*sample_quantity(p=0.7, max_qty=10) + np.random.randint(-500,500))

# %%
n_products = 100
products_df = pd.DataFrame(
    [as_product(data.iloc[i]) for i in np.random.choice(data.shape[0], size=n_products, replace=False)],
    columns=["name", "category", "price", "supplier_id", "stock_quantity"]
)
products_df["product_id"] = np.arange(1, n_products+1)
products_df = products_df[["product_id", "name", "category", "price", "supplier_id", "stock_quantity"]]
products_df.head()
# Out:
#    product_id                           name           category  price  \
# 0           1     CATWALK31 - Footwear-Women     Footwear-Women  12.20
# 1           2     AND288 - Westernwear-Women  Westernwear-Women   9.25
# 2           3      DRW78 - Westernwear-Women  Westernwear-Women  13.07
# 3           4     BIBA276 - Indianwear-Women   Indianwear-Women  11.76
# 4           5  AURELIA414 - Indianwear-Women   Indianwear-Women   7.62
#
#    supplier_id  stock_quantity
# 0           58            1363
# 1           18            1300
# 2           31            1107
# 3           24            1568
# 4           11             707

# %%
plt.hist(products_df.stock_quantity, bins=20);plt.show()

# %%
products_df.category.value_counts()
# Out:
# category
# Westernwear-Women           35
# Indianwear-Women            19
# Lingerie&Nightwear-Women    14
# Jewellery-Women             10
# Footwear-Women               9
# Watches-Women                8
# Fragrance-Women              5
# Name: count, dtype: int64

# %% [markdown]
# ### Orders
#
# ```
# CREATE TABLE Orders (
#     order_id SERIAL PRIMARY KEY,
#     customer_id INT REFERENCES Customers(customer_id),
#     order_date TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     order_status VARCHAR(50) NOT NULL
# );
# ```
#
# * for each **customer_id** in [1,100]:
#     * **customer_id**: ...
#     * **order_date**: min_date of 3
#     * **order_status**: random.choice of pending/delivered/cancelled

# %%
n_orders = 100
order_id = np.arange(1, n_orders+1)
customer_id = np.arange(1, 101)
get_date = lambda minimum_date, k: generate_dates(minimum_date, delta=timedelta(days=3*365), n=1)[k][0]
get_status = lambda: np.random.choice(["Pending", "Shipped", "Delivered", "Cancelled"], p=[0.2, 0.5, 0.25, 0.05])

# %%
orders_df = pd.DataFrame({
    "order_id": order_id,
    "customer_id": np.random.choice(customer_id, size=n_orders, replace=True), # many orders to one customer
    "order_date": [get_date(datetime(2023,1,1), 0) for _ in range(n_orders)],
    "status": [get_status() for _ in range(n_orders)]
})
orders_df.head()
# Out:
#    order_id  customer_id order_date     status
# 0         1           61 2024-10-07  Delivered
# 1         2           44 2025-06-13  Delivered
# 2         3            9 2025-12-29    Pending
# 3         4           37 2023-04-20    Shipped
# 4         5           43 2023-11-03    Shipped

# %% [markdown]
# ### Order_items
#
# ```
# CREATE TABLE Order_Items (
#     order_item_id SERIAL PRIMARY KEY,
#     order_id INT REFERENCES Orders(order_id),
#     product_id INT REFERENCES Products(product_id),
#     quantity INT NOT NULL,
#     price_at_purchase DECIMAL(10, 2) NOT NULL
# );
# ```
#
# * for each **order_id** in [1,100]:
#     * **product_id**: random.choice(0,100)
#     * **quantity**: random
#     * **price_at_purchase**: Products.Price where product_id

# %%
n_order_items = 300
order_items_id = np.arange(1, n_order_items+1)
order_id = np.random.choice(orders_df.order_id, size=n_order_items, replace=True)  # many items to one order 
product_id = np.random.choice(products_df.product_id, size=n_order_items, replace=True)  # many items to one product
quantity = [sample_quantity(p=0.7, max_qty=20) for _ in range(n_order_items)]

# for each order item, get the price of the product at time of order
price_lookup = products_df.set_index("product_id")["price"].to_dict()

order_items_df = pd.DataFrame({
    "order_items_id": order_items_id,
    "order_id": order_id,
    "product_id": product_id,
    "quantity": quantity,
    "price_at_purchase": [price_lookup[pid] for pid in product_id]
})
order_items_df.head()
#get new price_at_purchase column based on product price at time of order (leave other columns as is)

#order_items_df["price_at_purchase"] = order_items_df["product_id"].apply(lambda pid: price_lookup.get(pid, 0))
#order_items_df.head()
# Out:
#    order_items_id  order_id  product_id  quantity  price_at_purchase
# 0               1        33          20         2              17.54
# 1               2        15          56         1              16.88
# 2               3        52          34         3               9.91
# 3               4        74          37         2              19.61
# 4               5        73          39         2              32.25

# %%
# plot quantity distribution
plt.hist(order_items_df.quantity, bins=20);plt.show()

# %% [markdown]
# ### Shipments
#
# ```
# CREATE TABLE Shipments (
#     shipment_id SERIAL PRIMARY KEY,
#     order_id INT REFERENCES Orders(order_id),
#     shipped_date TIMESTAMP,
#     delivery_date TIMESTAMP,
#     shipping_cost DECIMAL(10, 2) NOT NULL
# );
# ```
#
# * for each **order_id** in [1,100]:
#     * **order_id**: ...
#     * **shipped_date** < **delivery_date** : random.choice(date_range(start=order_id.order_date,end=+week))
#     * **delivery_date**:
#     * **shipping_cost**: (random.randn * factor + shift) * order_item.quantity

# %%
n_shipments = n_orders
shipment_id = np.arange(1, n_shipments+1)
order_id = orders_df.order_id.copy()  # one to one with orders
# shipped_date must be after order_date
shipped_date = [
    generate_dates(pd.to_datetime(orders_df.loc[orders_df.order_id == oid, "order_date"].values[0]), delta=timedelta(days=7), n=1)[0][0]
    for oid in order_id
]
delivery_date = [
    generate_dates(shipped_date[i], delta=timedelta(days=14), n=1)[0][0]
    for i in range(n_shipments)
]
if not np.where(shipped_date<delivery_date, True, False).all():
    raise ValueError("Some shipped_date is not before delivery_date")

shipments_df = pd.DataFrame({
    "shipment_id": shipment_id,
    "order_id": order_id,
    "shipped_date": shipped_date,
    "delivery_date": delivery_date
})

# shipping_cost based on quantity of items in the order so we need to get the order_items_df to calculate it
#shipping_cost = []
#for oid in order_id:
#    total_quantity = order_items_df.loc[order_items_df.order_id == oid, "quantity"].sum()
#    cost = 5.0 + 0.5 * total_quantity  # base cost + per item cost
#    shipping_cost.append(round(cost, 2))

# Items per order (sum quantities across order_items)
qty_per_order = order_items_df.groupby("order_id")["quantity"].sum()
items_per_order = np.array([qty_per_order.get(oid, 0) for oid in order_id])

# Gamma model: positive, right-skewed, mean tied to items
base = 4.0       # base handling
per_item = 1.2   # variable per item
k = 6.0          # gamma shape; higher -> lower variance
mu = base + per_item * items_per_order
theta = mu / k
shipping_cost = np.random.gamma(shape=k, scale=theta, size=n_shipments)

# Optional alternative (lognormal multiplicative noise):
# sigma = 0.35
# shipping_cost = (base + per_item * items_per_order) * np.random.lognormal(mean=0.0, sigma=sigma, size=n_shipments)

min_cost = 3.0
shipments_df["shipping_cost"] = np.round(np.maximum(shipping_cost, min_cost), 2)
    

shipments_df.head()
# Out:
#    shipment_id  order_id shipped_date delivery_date  shipping_cost
# 0            1         1   2025-02-17    2025-03-02          11.16
# 1            2         2   2023-06-11    2023-06-25           5.16
# 2            3         3   2025-04-07    2025-04-17           7.84
# 3            4         4   2024-02-11    2024-02-13          12.05
# 4            5         5   2023-02-24    2023-02-28           7.17

# %%
plt.hist(shipments_df.shipping_cost, bins=20);plt.show()

# %%
outpath = "../data/"
products_df.to_csv(outpath + "products_generated.csv", index=False)
orders_df.to_csv(outpath + "orders_generated.csv", index=False)
order_items_df.to_csv(outpath + "order_items_generated.csv", index=False)
shipments_df.to_csv(outpath + "shipments_generated.csv", index=False)
